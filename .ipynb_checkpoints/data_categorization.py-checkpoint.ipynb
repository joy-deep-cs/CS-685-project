# %%
import pandas as pd
import sklearn
import numpy as np
import scipy 
from os import listdir
from os.path import isfile, join
import json
import glob
import nltk
import gensim
from gensim.models.phrases import Phrases, Phraser
from sklearn.model_selection import train_test_split

# %%
mypath = "/Users/admin/Desktop/phd/CS-685-project/"
dataDir = mypath+"/data/"
allFiles = [f for f in listdir(dataDir) if isfile(join(dataDir, f))]
allFiles = [f for f in allFiles if "json" in f]

# allFiles = ['complaints_2020-10-08_fixed.json']

# %%
print(allFiles)
reports = []

for fi in allFiles:
    print(fi)
    for file in glob.glob(dataDir+fi):
        for line in open(file, "r"):
            #print(line[179])
#             print(line)
            reports.append(json.loads(line))
# Out:
# ['complaints_Delhi.json', 'complaints_Odisha.json', 'complaints_Bangalore.json', 'complaints_2020-10-08_fixed_bangalore.json', 'complaints_Mumbai.json']
# complaints_Delhi.json
# complaints_Odisha.json
# complaints_Bangalore.json
# complaints_2020-10-08_fixed_bangalore.json
# complaints_Mumbai.json

# %%
import pandas as pd
df = pd.DataFrame(reports)
df
# Out:
#             id                                        description  \
# 0      1943280  Z6-W61,SHIVA HOMES,A-sahu mangalam bhawan ke b...
# 1      1922159                           Sanitization is not here
# 2      1852336        Z1-W41,Ram nagar nahar Kinare M. 9479010167
# 3      1790436  Z1,w60,AKANSHA KUNJ,A-Shiv mandir pas,h.no. 21...
# 4      1788056  Z3 w34 aanand nagar A-fokat para sai mandir ke...
# ...        ...                                                ...
# 46003   451071  कांजूरमार्ग, भांडूप और मुलुंड मे जो मेट्रो का ...
# 46004   448830  Despite being a MHADA building, there is no wa...
# 46005   448707  Broken Footpath full of debris near hiranandan...
# 46006   448255  Near by two tanks police station there is nawa...
# 46007   447953  There is no municipal water connection in our ...
#
#                                                 location  \
# 0      E-111, Om Vihar Extn, Param Puri, Uttam Nagar,...
# 1      Sanjay Amar Colony, Vishwas Nagar, Shahdara, D...
# 2      Shop No.AB-399, Amar Puri, Nabi karim, Paharga...
# 3      B5 Rd, Pocket 14, Sector 9, Rohini, Delhi, 110085
# 4                                              Raja tala
# ...                                                  ...
# 46003  Kanjurmarg West, Bhandup West, Mumbai, Maharas...
# 46004  Marathon Mhada, Dainik Shivneri Road, Ganapatr...
# 46005  10-A, Orchard Ave, Hiranandani Gardens, Powai,...
# 46006  130, Ms Ali Road, Ajmer, Kumbharwada, Mumbai, ...
# 46007  Laxmi Nagar, Rahmat Nagar, Oswal Nagari, Nalas...
#
#                                                image_url  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 46003                                                 []
# 46004                                                 []
# 46005  [https://jccd-ichangemycity-complaints.s3.ap-s...
# 46006  [https://jccd-ichangemycity-complaints.s3.ap-s...
# 46007                                                 []
#
#                    postedOn                                        category  \
# 0      2020-12-02 T12:06:57                                  Animal Catcher
# 1      2020-11-29 T13:06:58                                 Toilet My Right
# 2      2020-11-18 T13:06:58                          Solid Waste Management
# 3      2020-11-02 T13:06:58                                          Others
# 4      2020-11-02 T13:06:58                          Solid Waste Management
# ...                     ...                                             ...
# 46003  2019-12-03 T13:00:35  Mobility - Roads, Footpaths and Infrastructure
# 46004  2019-12-03 T13:00:35                Garbage and Unsanitary Practices
# 46005  2019-12-03 T13:00:39  Mobility - Roads, Footpaths and Infrastructure
# 46006  2019-12-03 T13:00:40                                Animal Husbandry
# 46007  2019-12-03 T13:00:40                       Water Supply and Services
#
#                                              subCategory  \
# 0                                                    Dog
# 1                    No Water Supply In Public Toilet(s)
# 2                      Collection And Removal Of Garbage
# 3                                         Other Services
# 4                                      Cleaning Of Drain
# ...                                                  ...
# 46003                      Construction of new footpaths
# 46004        Implementation Of Waste Segregation/Garbage
# 46005                      Construction of new footpaths
# 46006  Stray Dog Sterilisation/Animal Birth Control (...
# 46007                               Regular Water Supply
#
#                                               myCategory  page
# 0                                                    Dog     1
# 1                    No Water Supply In Public Toilet(s)     1
# 2                      Collection And Removal Of Garbage     1
# 3                                         Other Services     1
# 4                                      Cleaning Of Drain     1
# ...                                                  ...   ...
# 46003                      Construction of new footpaths    14
# 46004        Implementation Of Waste Segregation/Garbage    14
# 46005                      Construction of new footpaths    14
# 46006  Stray Dog Sterilisation/Animal Birth Control (...    14
# 46007                               Regular Water Supply    14
#
# [46008 rows x 9 columns]

# %%
wordsList = [nltk.word_tokenize(text) for text in df["description"]]
cleanWordsList = []

def checkWord(word):
    if(len(word)<=1):
        return False
    for ch in word:
        if((ch>='a' and ch<= 'z') or (ch>='A' and ch<='Z')):
            return True
    return False
    
for words in wordsList:
    wordList = []
    for word in words:
        if(checkWord(word)):
            wordList.append(word.lower())
    cleanWordsList.append(wordList)
    
    
df["words"] = cleanWordsList

# %%
set(df["category"])
# Out:
# {'Animal Catcher',
#  'Animal Husbandry',
#  'Certificates',
#  'Community Infrastructure',
#  'Covid 19',
#  'Crime and Safety',
#  'EMP Grievance Redressal',
#  'Electricity & Power',
#  'Electricity and Power Supply',
#  'Fire Pollution',
#  'Fire Safety',
#  'Garbage and Unsanitary Practices',
#  'Lakes',
#  'Mobility - Roads, Footpaths and Infrastructure',
#  'Mobility - Roads, Public transport',
#  'Others',
#  'PWD',
#  'Parks & Recreation',
#  'Pension',
#  'Playgrounds',
#  'Pollution',
#  'Power supply',
#  'Proibition & Sale of Tobacco products, Plastic carry bags',
#  'Public Toilets',
#  'Public Transport - BMTC',
#  'Public Transport - KSRTC',
#  'Ration Card',
#  'Safety and Crime',
#  'Sanitation',
#  'Sewerage Systems',
#  'Solid Waste Management',
#  'Storm Water Drains',
#  'Street lighting',
#  'Toilet My Right',
#  'Traffic and Road Safety',
#  'Trees and Saplings',
#  'Water Supply',
#  'Water Supply Department',
#  'Water Supply and Services'}

# %%
broadCat = {'Animal Catcher': 'Animal',
 'Animal Husbandry': 'Animal',
 'Certificates':'other',
 'Community Infrastructure':'Infrastructure',
 'Covid 19':'covid',
 'Crime and Safety':'Crime and Safety',
 'EMP Grievance Redressal':'Grievance Redressal',
 'Electricity & Power':"Electricity",
 'Electricity and Power Supply':"Electricity",
 'Fire Pollution':"pollution",
 'Fire Safety':"Infrastructure",
 'Garbage and Unsanitary Practices':"cleanliness",
 'Lakes':"pollution",
 'Mobility - Roads, Footpaths and Infrastructure':"transport",
 'Mobility - Roads, Public transport':"transport",
 'Others':"other",
 'PWD':"Infrastructure",
 'Parks & Recreation':"lifestyle",
 'Pension':"Grievance Redressal",
 'Playgrounds':"lifestyle",
 'Pollution':"pollution",
 'Power supply':"Electricity",
 'Proibition & Sale of Tobacco products, Plastic carry bags':"pollution",
 'Public Toilets':"cleanliness",
 'Public Transport - BMTC':"transport",
 'Public Transport - KSRTC':"transport",
 'Ration Card':"Grievance Redressal",
 'Safety and Crime':"Crime and Safety",
 'Sanitation':"cleanliness",
 'Sewerage Systems':"Infrastructure",
 'Solid Waste Management':"pollution",
 'Storm Water Drains':"Infrastructure",
 'Street lighting':"Infrastructure",
 'Toilet My Right':"cleanliness",
 'Traffic and Road Safety':"transport",
 'Trees and Saplings':"Tree",
 'Water Supply':"water",
 'Water Supply Department':"water",
 'Water Supply and Services':"water"}

# %%
df["broadCategory"] = df["category"].apply(lambda x: broadCat[x])
print(set(df["broadCategory"]))
def split(df, col):
    trainDfs = []
    testDfs = []
    for cat in set(df[col]):
        tempDf = df[df[col] == cat]
        if(len(tempDf.index)<=2):
            tempTrain = tempDf
            tempTest = tempDf
        else:
            tempTrain, tempTest = train_test_split(tempDf, test_size=0.3, random_state=42)
        trainDfs.append(tempTrain)
        testDfs.append(tempTest)
    train = pd.concat(trainDfs)
    test = pd.concat(testDfs)
    return train,test

train,test = split(df, "broadCategory")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-7f3dbb6cf8b5> in <module>
# ----> 1 df["broadCategory"] = df["category"].apply(lambda x: broadCategory[x])
#       2 print(set(df["broadCategory"]))
#       3 def split(df, col):
#       4     trainDfs = []
#       5     testDfs = []
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-79-7f3dbb6cf8b5> in <lambda>(x)
# ----> 1 df["broadCategory"] = df["category"].apply(lambda x: broadCategory[x])
#       2 print(set(df["broadCategory"]))
#       3 def split(df, col):
#       4     trainDfs = []
#       5     testDfs = []
#
# NameError: name 'broadCategory' is not defined

# %%
from gensim.models.doc2vec import TaggedDocument
train_tagged = train.apply(
    lambda r: TaggedDocument(words=r["words"], tags=[r.broadCategory]), axis=1)
test_tagged = test.apply(
    lambda r: TaggedDocument(words=r['words'], tags=[r.broadCategory]), axis=1)

# %%
import multiprocessing
from tqdm import tqdm
from gensim.models import Doc2Vec
from sklearn import utils

cores = multiprocessing.cpu_count()

model_dbow = Doc2Vec(dm=0, vector_size=300, negative=5, hs=0, min_count=2, sample = 0, workers=cores)
model_dbow.build_vocab([x for x in tqdm(train_tagged.values)])

for epoch in range(30):
    model_dbow.train(utils.shuffle([x for x in tqdm(train_tagged.values)]), total_examples=len(train_tagged.values), epochs=1)
    model_dbow.alpha -= 0.002
    model_dbow.min_alpha = model_dbow.alpha
# Out:
# 100%|██████████| 32196/32196 [00:00<00:00, 2108712.06it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3043973.84it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3209426.08it/s]
# WARNING:gensim.models.base_any2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3113668.70it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3111301.33it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3029156.83it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3025898.80it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3045072.08it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3227991.86it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3245291.19it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2066250.66it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3231158.61it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3002219.02it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2743819.32it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3127152.16it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3094829.99it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3116974.69it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3145654.72it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3139876.57it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2872331.89it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2925028.95it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2891459.04it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2967581.84it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2891892.49it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 2992240.45it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3085425.36it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3002486.03it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3107363.70it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3054370.12it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3108007.36it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 100%|██████████| 32196/32196 [00:00<00:00, 3063933.65it/s]
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
def vec_for_learning(model, tagged_docs):
    sents = tagged_docs.values
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in sents])
    return targets, regressors

# %%
from sklearn.linear_model import LogisticRegression


y_train, X_train = vec_for_learning(model_dbow, train_tagged)
y_test, X_test = vec_for_learning(model_dbow, test_tagged)
logreg = LogisticRegression(n_jobs=1, C=1e5)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
from sklearn.metrics import accuracy_score, f1_score
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# /Library/Python/3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Testing accuracy 0.4132542323831573
# Testing F1 score: 0.35233480032899983

# %%
model_dmm = Doc2Vec(dm=1, dm_mean=1, vector_size=300, window=10, negative=5, min_count=1, workers=5, alpha=0.065, min_alpha=0.065)
model_dmm.build_vocab([x for x in tqdm(train_tagged.values)])

for epoch in range(30):
    model_dmm.train(utils.shuffle([x for x in tqdm(train_tagged.values)]), total_examples=len(train_tagged.values), epochs=1)
    model_dmm.alpha -= 0.002
    model_dmm.min_alpha = model_dmm.alpha
# Out:
# 100%|██████████| 32196/32196 [00:00<00:00, 2130066.27it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2988532.10it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3105934.30it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3213779.76it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2543697.48it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3154325.09it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2912286.48it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2980024.53it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3139803.57it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3223061.04it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3074396.95it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3037605.98it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3066507.97it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3199389.02it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3141118.18it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3199768.06it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3055130.24it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2881095.17it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2985558.83it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3019741.31it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3027662.70it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3123680.03it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3148661.90it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2755352.21it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3141702.80it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3159047.69it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2565979.66it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2686343.70it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 3019403.71it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2585632.17it/s]
# 100%|██████████| 32196/32196 [00:00<00:00, 2893255.59it/s]

# %%
y_train, X_train = vec_for_learning(model_dmm, train_tagged)
y_test, X_test = vec_for_learning(model_dmm, test_tagged)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.5447113297641442
# Testing F1 score: 0.5357203634836858
# /Library/Python/3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
model_dbow.delete_temporary_training_data(keep_doctags_vectors=True, keep_inference=True)
model_dmm.delete_temporary_training_data(keep_doctags_vectors=True, keep_inference=True)

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec
new_model = ConcatenatedDoc2Vec([model_dbow, model_dmm])

# %%
def get_vectors(model, tagged_docs):
    sents = tagged_docs.values
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in sents])
    return targets, regressors

# %%
from sklearn.metrics import classification_report
y_train, X_train = get_vectors(new_model, train_tagged)
train = pd.DataFrame()
y_test, X_test = get_vectors(new_model, test_tagged)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))

print(classification_report(y_test,y_pred))
# Out:
# /Library/Python/3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Testing accuracy 0.539212849081175
# Testing F1 score: 0.5000606809454393
# /Library/Python/3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                            precision    recall  f1-score   support
#
#                                            Animal Catcher       0.00      0.00      0.00         4
#                                          Animal Husbandry       0.39      0.21      0.27       912
#                                              Certificates       0.67      0.02      0.05        84
#                                  Community Infrastructure       0.39      0.03      0.06       353
#                                                  Covid 19       0.00      0.00      0.00         4
#                                          Crime and Safety       0.00      0.00      0.00        33
#                                   EMP Grievance Redressal       0.00      0.00      0.00         1
#                                       Electricity & Power       0.00      0.00      0.00         1
#                              Electricity and Power Supply       0.78      0.21      0.33        68
#                                            Fire Pollution       0.00      0.00      0.00         1
#                                               Fire Safety       0.00      0.00      0.00         4
#                          Garbage and Unsanitary Practices       0.51      0.63      0.56      3914
#                                                     Lakes       1.00      0.04      0.08        25
#            Mobility - Roads, Footpaths and Infrastructure       0.57      0.65      0.61      4995
#                        Mobility - Roads, Public transport       0.00      0.00      0.00         1
#                                                    Others       0.00      0.00      0.00        77
#                                                       PWD       0.00      0.00      0.00         2
#                                        Parks & Recreation       0.50      0.04      0.07        51
#                                                   Pension       0.00      0.00      0.00         1
#                                               Playgrounds       0.00      0.00      0.00         2
#                                                 Pollution       0.00      0.00      0.00       155
#                                              Power supply       0.00      0.00      0.00         1
# Proibition & Sale of Tobacco products, Plastic carry bags       0.00      0.00      0.00         1
#                                            Public Toilets       0.00      0.00      0.00         7
#                                   Public Transport - BMTC       0.00      0.00      0.00        10
#                                  Public Transport - KSRTC       0.00      0.00      0.00         1
#                                               Ration Card       0.00      0.00      0.00         1
#                                          Safety and Crime       0.00      0.00      0.00         2
#                                                Sanitation       0.00      0.00      0.00         2
#                                          Sewerage Systems       0.00      0.00      0.00       171
#                                    Solid Waste Management       0.00      0.00      0.00         6
#                                        Storm Water Drains       0.23      0.03      0.05       497
#                                           Street lighting       0.57      0.71      0.63      2075
#                                           Toilet My Right       0.00      0.00      0.00         8
#                                   Traffic and Road Safety       0.00      0.00      0.00       117
#                                        Trees and Saplings       0.72      0.13      0.22       138
#                                              Water Supply       0.00      0.00      0.00         2
#                                   Water Supply Department       0.00      0.00      0.00         2
#                                 Water Supply and Services       0.56      0.05      0.10        93
#
#                                                  accuracy                           0.54     13822
#                                                 macro avg       0.18      0.07      0.08     13822
#                                              weighted avg       0.50      0.54      0.50     13822

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
# print(X_train)

# print(list(y_train))
# train = pd.DataFrame()
# test = pd.DataFrame()
# train["feature"] = list(X_train)
# print(list(X_train)[0])
# train["label"] = list(y_train)
model.fit(np.array(X_train), np.array(y_train))
y_pred = model.predict(np.array(X_test))
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.55512950368977
# Testing F1 score: 0.5273717176063586

# %%
print(classification_report(y_test,y_pred))
# Out:
#                                                            precision    recall  f1-score   support
#
#                                            Animal Catcher       0.00      0.00      0.00         4
#                                          Animal Husbandry       0.50      0.21      0.30       912
#                                              Certificates       0.43      0.37      0.40        84
#                                  Community Infrastructure       0.41      0.05      0.10       353
#                                                  Covid 19       0.00      0.00      0.00         4
#                                          Crime and Safety       1.00      0.03      0.06        33
#                                   EMP Grievance Redressal       0.00      0.00      0.00         1
#                                       Electricity & Power       0.00      0.00      0.00         1
#                              Electricity and Power Supply       0.37      0.41      0.39        68
#                                            Fire Pollution       0.00      0.00      0.00         1
#                                               Fire Safety       0.00      0.00      0.00         4
#                          Garbage and Unsanitary Practices       0.49      0.68      0.57      3914
#                                                     Lakes       0.22      0.20      0.21        25
#            Mobility - Roads, Footpaths and Infrastructure       0.59      0.66      0.62      4995
#                        Mobility - Roads, Public transport       0.00      0.00      0.00         1
#                                                    Others       0.00      0.00      0.00        77
#                                                       PWD       0.00      0.00      0.00         2
#                                        Parks & Recreation       0.22      0.25      0.23        51
#                                                   Pension       0.00      0.00      0.00         1
#                                               Playgrounds       0.00      0.00      0.00         2
#                                                 Pollution       0.57      0.03      0.05       155
#                                              Power supply       0.00      0.00      0.00         1
# Proibition & Sale of Tobacco products, Plastic carry bags       0.00      0.00      0.00         1
#                                            Public Toilets       0.00      0.00      0.00         7
#                                   Public Transport - BMTC       0.00      0.00      0.00        10
#                                  Public Transport - KSRTC       0.00      0.00      0.00         1
#                                               Ration Card       0.00      0.00      0.00         1
#                                          Safety and Crime       0.00      0.00      0.00         2
#                                                Sanitation       0.00      0.00      0.00         2
#                                          Sewerage Systems       0.57      0.05      0.09       171
#                                    Solid Waste Management       0.00      0.00      0.00         6
#                                        Storm Water Drains       0.36      0.12      0.18       497
#                                           Street lighting       0.71      0.63      0.67      2075
#                                           Toilet My Right       0.00      0.00      0.00         8
#                                   Traffic and Road Safety       0.17      0.01      0.02       117
#                                        Trees and Saplings       0.33      0.21      0.26       138
#                                              Water Supply       0.00      0.00      0.00         2
#                                   Water Supply Department       0.00      0.00      0.00         2
#                                 Water Supply and Services       0.53      0.19      0.28        93
#
#                                                  accuracy                           0.56     13822
#                                                 macro avg       0.19      0.11      0.11     13822
#                                              weighted avg       0.55      0.56      0.53     13822

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
print(classification_report(y_test,y_pred))
# Out:
# Testing accuracy 0.3882940240196788
# Testing F1 score: 0.2459410106272814
# /Library/Python/3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                            precision    recall  f1-score   support
#
#                                            Animal Catcher       0.00      0.00      0.00         4
#                                          Animal Husbandry       0.00      0.00      0.00       912
#                                              Certificates       0.00      0.00      0.00        84
#                                  Community Infrastructure       0.00      0.00      0.00       353
#                                                  Covid 19       0.00      0.00      0.00         4
#                                          Crime and Safety       0.00      0.00      0.00        33
#                                   EMP Grievance Redressal       0.00      0.00      0.00         1
#                                       Electricity & Power       0.00      0.00      0.00         1
#                              Electricity and Power Supply       0.00      0.00      0.00        68
#                                            Fire Pollution       0.00      0.00      0.00         1
#                                               Fire Safety       0.00      0.00      0.00         4
#                          Garbage and Unsanitary Practices       0.66      0.02      0.04      3914
#                                                     Lakes       0.00      0.00      0.00        25
#            Mobility - Roads, Footpaths and Infrastructure       0.37      1.00      0.54      4995
#                        Mobility - Roads, Public transport       0.00      0.00      0.00         1
#                                                    Others       0.00      0.00      0.00        77
#                                                       PWD       0.00      0.00      0.00         2
#                                        Parks & Recreation       0.00      0.00      0.00        51
#                                                   Pension       0.00      0.00      0.00         1
#                                               Playgrounds       0.00      0.00      0.00         2
#                                                 Pollution       0.00      0.00      0.00       155
#                                              Power supply       0.00      0.00      0.00         1
# Proibition & Sale of Tobacco products, Plastic carry bags       0.00      0.00      0.00         1
#                                            Public Toilets       0.00      0.00      0.00         7
#                                   Public Transport - BMTC       0.00      0.00      0.00        10
#                                  Public Transport - KSRTC       0.00      0.00      0.00         1
#                                               Ration Card       0.00      0.00      0.00         1
#                                          Safety and Crime       0.00      0.00      0.00         2
#                                                Sanitation       0.00      0.00      0.00         2
#                                          Sewerage Systems       0.00      0.00      0.00       171
#                                    Solid Waste Management       0.00      0.00      0.00         6
#                                        Storm Water Drains       0.00      0.00      0.00       497
#                                           Street lighting       0.91      0.15      0.26      2075
#                                           Toilet My Right       0.00      0.00      0.00         8
#                                   Traffic and Road Safety       0.00      0.00      0.00       117
#                                        Trees and Saplings       0.00      0.00      0.00       138
#                                              Water Supply       0.00      0.00      0.00         2
#                                   Water Supply Department       0.00      0.00      0.00         2
#                                 Water Supply and Services       0.00      0.00      0.00        93
#
#                                                  accuracy                           0.39     13822
#                                                 macro avg       0.05      0.03      0.02     13822
#                                              weighted avg       0.46      0.39      0.25     13822

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=0)
gpc.fit(X_train, y_train)
y_pred = gpc.predict(X_test)
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
print(classification_report(y_test,y_pred))
