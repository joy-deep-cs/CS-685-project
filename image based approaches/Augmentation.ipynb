# %%
import json
import glob
reports = []
for file in glob.glob("/home/pramit67/Downloads/complaints_fixed (1).json"):
    for line in open(file, "r"):
        #print(line[179])
        reports.append(json.loads(line))

# %%
type(reports)
import pandas as pd
df1 = pd.DataFrame(reports)
#print(df1)
arr=df1.iloc[:,0].to_numpy()
arr1=df1.iloc[:,2].to_numpy()
arr2=df1.iloc[:,4].to_numpy()
arr3=df1.iloc[:,5].to_numpy()
df2=pd.DataFrame()
df2['id']=arr
df2['location']=arr1
df2['Date']=arr2
df2['category']=arr3
df3=pd.DataFrame()
df3['Date']=arr2
df3['category']=arr3
print(df2.head)
df2.to_csv('/home/pramit67/complaints.csv',index=False)
df3.to_csv('/home/pramit67/complaintsinsight.csv',index=False)
# Out:
# <bound method NDFrame.head of             id                                           location  \
# 0      1701787                Vgp Layout, Kudlu, Karnataka, India
# 1      1701702  #127/a,1St Floor,4Th Main ,7Th Cross Dollers C...
# 2      1700917  Corner Cafe, Someshwara Layout, Doddakannelli,...
# 3      1699399  674, Marenahalli Rd, 8Th Block, 1St Phase, J. ...
# 4      1697683  36/2, 13Th A Main Rd, Malleshwaram, Bengaluru,...
# ...        ...                                                ...
# 44955   438570  Malleswaram Circle Bus Stop, Venkata Ranga Iye...
# 44956   438563  27Th Main Rd, Btm 2Nd Stage, Kuvempu Nagar, St...
# 44957   438554                              SUDHMANAGAR nala road
# 44958   438547  Anjaneya Nagar, Ittamadu, Banashankari 3Rd Sta...
# 44959   438544                                     Hosakerehalli,
#
#                        Date                                        category
# ...

# %%
arr=df1['id'].to_numpy()
arr1=df1['category'].to_numpy()
arr2=df1['subCategory'].to_numpy()
arr3=df['imagename'].to_numpy()
arr=arr.tolist()

arr1=arr1.tolist()
arr2=arr2.tolist()
arr3=arr3.tolist()
arr4=set(arr)
arr5=set(arr3)
arr6=arr4.intersection(arr5)
arr6=list(arr6)
arr_final=[]

category=[]
subcategory=[]
for i in range(0,len(arr6)):
    
    if(arr6[i] in arr ):
        arr_final.append(arr6[i])
        index=arr.index(arr6[i])

        category.append(arr1[index])
        subcategory.append(arr2[index])
print(len(category))
print(len(subcategory))
uniquesub=subcategory
uniquesub=np.array(uniquesub)
uniquesub=np.unique(uniquesub)
print(uniquesub)
print(len(uniquesub))
'''
df3=pd.DataFrame()
df3['image-name']=arr_final
df3['category']=category
df3['subCategory']=subcategory
print(df3)
df3.to_csv('/home/pramit67/images_final1.csv',index=False)
arr7=set(arr_final)
arr8=arr5-arr7
print(arr8)
'''

# %%
import os
import pandas as pd
mylist = os.listdir('/home/pramit67/Downloads/CS685')
#print(mylist)
mylist_updated=[]
df=pd.DataFrame()
for i in range(0,len(mylist)):
    s=mylist[i].split('_')[0]
    mylist_updated.append(int(s))
df['imagename']=mylist_updated
arr3=df['imagename'].to_numpy()
arr5=set(arr3)
print(len(arr3))
print(len(arr7))
arr8=arr5-arr7
print(arr8)

# %%
import cv2
import numpy as np
from skimage import io 
from skimage.transform import rotate, AffineTransform, warp
import matplotlib.pyplot as plt
import random
from skimage import img_as_ubyte
import os
from skimage.util import random_noise
import os

# %%
#Lets define functions for each operation
def anticlockwise_rotation(image):
    angle= random.randint(0,180)
    return rotate(image, angle)

def clockwise_rotation(image):
    angle= random.randint(0,180)
    return rotate(image, -angle)

def h_flip(image):
    return  np.fliplr(image)

def v_flip(image):
    return np.flipud(image)

def add_noise(image):
    return random_noise(image)

def blur_image(image):
    return cv2.GaussianBlur(img, (9,9),0)

#I would not recommend warp_shifting, because it distorts image, but can be used in many use case like 
#classifying blur and non-blur images
def warp_shift(image): 
    transform = AffineTransform(translation=(0,40))  #chose x,y values according to your convinience
    warp_image = warp(image, transform, mode="wrap")
    return warp_image

# %%
transformations = {'rotate anticlockwise': anticlockwise_rotation,
                      'rotate clockwise': clockwise_rotation,
                      'horizontal flip': h_flip, 
                      'vertical flip': v_flip,
                   'warp shift': warp_shift,
                   'adding noise': add_noise,
                   'blurring image':blur_image
                 }                

images_path="/home/pramit67/Downloads/CS685/Street Lighting" 
augmented_path="/home/pramit67/Downloads/CS685/Street Lighting" 
images=[]

for im in os.listdir(images_path):     
    images.append(os.path.join(images_path,im))

images_to_generate=175
i=1                        


while i<=images_to_generate:    
    image=random.choice(images)
    original_image = io.imread(image)
    transformed_image=None
#     print(i)
    n = 0       
    transformation_count = random.randint(1, len(transformations)) #choose random number of transformation to apply on the image
    
    while n <= transformation_count:
        key = random.choice(list(transformations)) 
        transformed_image = transformations[key](original_image)
        n = n + 1
        
    new_image_path= "%s/augmented_image_%s.jpg" %(augmented_path, i+640)
    transformed_image = img_as_ubyte(transformed_image)  #Convert an image to unsigned byte format, with values in [0, 255].
    transformed_image=cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB) #convert image to RGB before saving it
    cv2.imwrite(new_image_path, transformed_image) # save transformed image to path
    i =i+1

# %%
transformations = {'rotate anticlockwise': anticlockwise_rotation,
                      'rotate clockwise': clockwise_rotation,
                      'horizontal flip': h_flip, 
                      'vertical flip': v_flip,
                   'warp shift': warp_shift,
                   'adding noise': add_noise,
                   'blurring image':blur_image
                 }                

images_path="/home/pramit67/Downloads/CS685/Traffic and Road Safety" 
augmented_path="/home/pramit67/Downloads/CS685/Traffic and Road Safety" 
images=[]

for im in os.listdir(images_path):     
    images.append(os.path.join(images_path,im))

images_to_generate=10
i=1                        


while i<=images_to_generate:    
    image=random.choice(images)
    original_image = io.imread(image)
    transformed_image=None
#     print(i)
    n = 0       
    transformation_count = random.randint(1, len(transformations)) #choose random number of transformation to apply on the image
    
    while n <= transformation_count:
        key = random.choice(list(transformations)) 
        transformed_image = transformations[key](original_image)
        n = n + 1
        
    new_image_path= "%s/augmented_image_%s.jpg" %(augmented_path, i+815)
    transformed_image = img_as_ubyte(transformed_image)  #Convert an image to unsigned byte format, with values in [0, 255].
    transformed_image=cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB) #convert image to RGB before saving it
    cv2.imwrite(new_image_path, transformed_image) # save transformed image to path
    i =i+1

# %%
transformations = {'rotate anticlockwise': anticlockwise_rotation,
                      'rotate clockwise': clockwise_rotation,
                      'horizontal flip': h_flip, 
                      'vertical flip': v_flip,
                   'warp shift': warp_shift,
                   'adding noise': add_noise,
                   'blurring image':blur_image
                 }                

images_path="/home/pramit67/Downloads/CS685/Trees and Saplings" 
augmented_path="/home/pramit67/Downloads/CS685/Trees and Saplings" 
images=[]

for im in os.listdir(images_path):     
    images.append(os.path.join(images_path,im))

images_to_generate=50
i=1                        


while i<=images_to_generate:    
    image=random.choice(images)
    original_image = io.imread(image)
    transformed_image=None
#     print(i)
    n = 0       
    transformation_count = random.randint(1, len(transformations)) #choose random number of transformation to apply on the image
    
    while n <= transformation_count:
        key = random.choice(list(transformations)) 
        transformed_image = transformations[key](original_image)
        n = n + 1
        
    new_image_path= "%s/augmented_image_%s.jpg" %(augmented_path, i+825)
    transformed_image = img_as_ubyte(transformed_image)  #Convert an image to unsigned byte format, with values in [0, 255].
    transformed_image=cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB) #convert image to RGB before saving it
    cv2.imwrite(new_image_path, transformed_image) # save transformed image to path
    i =i+1

# %%
transformations = {'rotate anticlockwise': anticlockwise_rotation,
                      'rotate clockwise': clockwise_rotation,
                      'horizontal flip': h_flip, 
                      'vertical flip': v_flip,
                   'warp shift': warp_shift,
                   'adding noise': add_noise,
                   'blurring image':blur_image
                 }                

images_path="/home/pramit67/Downloads/CS685/Trees and Saplings" 
augmented_path="/home/pramit67/Downloads/CS685/Trees and Saplings" 
images=[]

for im in os.listdir(images_path):     
    images.append(os.path.join(images_path,im))

images_to_generate=50
i=1                        


while i<=images_to_generate:    
    image=random.choice(images)
    original_image = io.imread(image)
    transformed_image=None
#     print(i)
    n = 0       
    transformation_count = random.randint(1, len(transformations)) #choose random number of transformation to apply on the image
    
    while n <= transformation_count:
        key = random.choice(list(transformations)) 
        transformed_image = transformations[key](original_image)
        n = n + 1
        
    new_image_path= "%s/augmented_image_%s.jpg" %(augmented_path, i+875)
    transformed_image = img_as_ubyte(transformed_image)  #Convert an image to unsigned byte format, with values in [0, 255].
    transformed_image=cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB) #convert image to RGB before saving it
    cv2.imwrite(new_image_path, transformed_image) # save transformed image to path
    i =i+1
